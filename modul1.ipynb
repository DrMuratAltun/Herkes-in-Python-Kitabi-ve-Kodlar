# %% [markdown]
# Giriş, Python'a Giriş

# %%
x=19
if (x<20):
  print ("Merhaba")
# Out:
# Merhaba

# %%
Sayi1=5
Sayi1="Bilişim"
print(Sayi1)
# Out:
# Bilişim

# %%
kurum="ÖYGM"
print (Kurum)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8d1ac8bf8b4b> in <module>()
#       1 kurum="ÖYGM"
# ----> 2 print (Kurum)
#
# NameError: name 'Kurum' is not defined
